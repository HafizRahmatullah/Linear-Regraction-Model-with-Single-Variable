# %%
import numpy as np
import pandas as pn
import matplotlib.pyplot as plt

# %%
data = pn.read_csv('/home/rahmat/Desktop/Data csv file for ML/lRSV.csv')
data.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
x = data[['area']].values
y = data['price'].values

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x,y)
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
model.predict(np.array([[2600]]))
# Out:
# array([533664.38356164])

# %% [markdown]
# a = model.coef_

# %%
b = model.intercept_

# %%
y = a*2600+b
y
# Out:
# array([533664.38356164])
